# %% [markdown]
# # Pandas Input Demo
#
# This notebook describes how to read data into Pandas from various sources

# %% [markdown]
# ## standard imports

# %%
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## read_csv()
# Read CSV files. The delimiters and escaped characters can be tweaked as needed. There is a huge number of options for this function.

# %%
df_csv = pd.read_csv('../DATA/airport_boardings.csv', thousands=',', index_col=1)

df_csv.head()
# Out:
#                                                 Airport  2001 Rank  \
# Code
# ATL   Atlanta, GA (Hartsfield-Jackson Atlanta Intern...          1
# ORD          Chicago, IL (Chicago O'Hare International)          2
# DFW        Dallas, TX (Dallas/Fort Worth International)          3
# DEN                   Denver, CO (Denver International)          6
# LAX         Los Angeles, CA (Los Angeles International)          4
#
#       2001 Total  2010 Rank  2010 Total  2011 Rank     Total  \
# Code
# ATL     36384264          1    42655392          1  33034788
# ORD     28626694          2    30033313          2  22367052
# DFW     25198256          3    26785739          3  20430281
# DEN     16397390          4    24965553          4  19190341
# LAX     22873307          5    22860849          5  18379418
#
#       Percent change 2001-2011  Percent change 2010-2011
# Code
# ATL                       -9.2                     -22.6
# ORD                      -21.9                     -25.5
# DFW                      -18.9                     -23.7
# DEN                       17.0                     -23.1
# LAX                      -19.6                     -19.6

# %% [markdown]
# ## read_table()
# Read text files (other than CSV). This function is very similar to *read_csv()* and shares most of its options. This is the best choice for tab-delimited, space-delimited, and other delimited flat file formats.

# %%
df_table = pd.read_table('../DATA/columns_of_numbers.txt', delim_whitespace=True)
# df_table.set_index = pd.date_range('1/1/2017', periods=len(df_table), freq='D')
df_table.head()
# Out:
#    Alpha  Beta  Gamma  Delta  Epsilon  Zeta
# 0     63    51     59     61       50     4
# 1     40    66      9     64       63    17
# 2     18    23      2     61        1     9
# 3     29     8     40     59       10    26
# 4     54     9     68      4       16    21

# %%
df_table.plot(kind='scatter', x='Alpha', y='Zeta')

# %% [markdown]
# ## read_sql(), read_sql_query(), read_sql_table()
# Read data from a SQL database. It requires a connection object from one of the Python modules that follows the DB API, or it can use a SQLAlchemy DB engine object. A dataframe is created from the rows in the result set.
#
# TODO: describe read_sql_table  read_sql_query

# %% [markdown]
# ### read_sql()
# read_sql() is a convenience function that delegates to either *read_sql_query()* or *read_sql_table()*, as appropriate.
# It takes a query (or a table name) and the database connection. If a table is specified, the connection must be a SQLAlchemy engine. If a query is specified, it can be either a SQLAlchemy engine or a DB API connection object, as from pymssql, pyodbc, pymysql, cx_oracle, psycopg, etc.

# %%
import sqlite3
# import pyodbc
# conn = pyodbc.connect('DSN...')
conn = sqlite3.connect('../DATA/presidents.db')
df_sql = pd.read_sql('select * from presidents', conn)
df_sql.head()
# Out:
#    termnum    lastname firstname   termstart     termend           birthplace  \
# 0        1  Washington    George  1789-04-30  1797-03-04  Westmoreland County
# 1        2       Adams      John  1797-03-04  1801-03-04   Braintree, Norfolk
# 2        3   Jefferson    Thomas  1801-03-04  1809-03-04    Albermarle County
# 3        4     Madison     James  1809-03-04  1817-03-04          Port Conway
# 4        5      Monroe     James  1817-03-04  1825-03-04  Westmoreland County
#
#       birthstate   birthdate   deathdate                    party
# 0       Virginia  1732-02-22  1799-12-14                 no party
# 1  Massachusetts  1735-10-30  1826-07-04               Federalist
# 2       Virginia  1743-04-13  1826-07-04  Democratic - Republican
# 3       Virginia  1751-03-16  1836-06-28  Democratic - Republican
# 4       Virginia  1758-04-28  1831-07-04  Democratic - Republican

# %% [markdown]
# ### read_sql_query()
# read_sql_query() populates a dataframe from a SQL query. Either a DB API connection or a SQLAlchemy engine may be specified.

# %%
df_sql = pd.read_sql_query('select * from presidents', conn)
df_sql.head()
# Out:
#    termnum    lastname firstname   termstart     termend           birthplace  \
# 0        1  Washington    George  1789-04-30  1797-03-04  Westmoreland County
# 1        2       Adams      John  1797-03-04  1801-03-04   Braintree, Norfolk
# 2        3   Jefferson    Thomas  1801-03-04  1809-03-04    Albermarle County
# 3        4     Madison     James  1809-03-04  1817-03-04          Port Conway
# 4        5      Monroe     James  1817-03-04  1825-03-04  Westmoreland County
#
#       birthstate   birthdate   deathdate                    party
# 0       Virginia  1732-02-22  1799-12-14                 no party
# 1  Massachusetts  1735-10-30  1826-07-04               Federalist
# 2       Virginia  1743-04-13  1826-07-04  Democratic - Republican
# 3       Virginia  1751-03-16  1836-06-28  Democratic - Republican
# 4       Virginia  1758-04-28  1831-07-04  Democratic - Republican

# %% [markdown]
# ### read_sql_table()
# read_sql_table() populates a dataframe with an entire SQL table. The connection must be a SQLAlchemy engine.

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///../DATA/presidents.db')
df_sql = pd.read_sql_table('presidents', engine)
df_sql.head()
# Out:
#    termnum    lastname firstname  termstart    termend           birthplace  \
# 0        1  Washington    George 1789-04-30 1797-03-04  Westmoreland County
# 1        2       Adams      John 1797-03-04 1801-03-04   Braintree, Norfolk
# 2        3   Jefferson    Thomas 1801-03-04 1809-03-04    Albermarle County
# 3        4     Madison     James 1809-03-04 1817-03-04          Port Conway
# 4        5      Monroe     James 1817-03-04 1825-03-04  Westmoreland County
#
#       birthstate  birthdate  deathdate                    party
# 0       Virginia 1732-02-22 1799-12-14                 no party
# 1  Massachusetts 1735-10-30 1826-07-04               Federalist
# 2       Virginia 1743-04-13 1826-07-04  Democratic - Republican
# 3       Virginia 1751-03-16 1836-06-28  Democratic - Republican
# 4       Virginia 1758-04-28 1831-07-04  Democratic - Republican

# %% [markdown]
# ## read_excel()
# Read data from an Excel spreadsheet. The spreadsheet may be on the local computer, or specified via a URL.
#
# <!-- TODO: use different spreadsheet for local -->

# %% [markdown]
# ### Local file

# %%
df_excel_local = pd.read_excel('../DATA/presidents.xlsx')
df_excel_local.head()
# Out:
#    Term   Last Name First Name  Birth Date  Death Date       Place of Birth  \
# 0     1  Washington     George  1732-02-22  1799-12-14  Westmoreland County
# 1     2       Adams       John  1735-10-30  1826-07-04   Braintree, Norfolk
# 2     3   Jefferson     Thomas  1743-04-13  1826-07-04    Albermarle County
# 3     4     Madison      James  1751-03-16  1836-06-28          Port Conway
# 4     5      Monroe      James  1758-04-28  1831-07-04  Westmoreland County
#
#   State of Birth Date took office Date left Office        Party affiliation
# 0       Virginia       1789-04-30       1797-03-04                 no party
# 1  Massachusetts       1797-03-04       1801-03-04               Federalist
# 2       Virginia       1801-03-04       1809-03-04  Democratic - Republican
# 3       Virginia       1809-03-04       1817-03-04  Democratic - Republican
# 4       Virginia       1817-03-04       1825-03-04  Democratic - Republican

# %% [markdown]
# ### URL

# %%
df_excel_url = pd.read_excel('http://qrc.depaul.edu/Excel_Files/Presidents.xls',
        na_values="NA()")
df_excel_url.head()
# Out:
#            President  Years in office  Year first inaugurated  \
# 0  George Washington              8.0                    1789
# 1         John Adams              4.0                    1797
# 2   Thomas Jefferson              8.0                    1801
# 3      James Madison              8.0                    1809
# 4       James Monroe              8.0                    1817
#
#    Age at inauguration State elected from  # of electoral votes  \
# 0                   57           Virginia                    69
# 1                   61      Massachusetts                   132
# 2                   57           Virginia                    73
# 3                   57           Virginia                   122
# 4                   58           Virginia                   183
#
#    # of popular votes  National total votes  Total electoral votes  \
# 0                 NaN                   NaN                     69
# 1                 NaN                   NaN                    139
# 2                 NaN                   NaN                    137
# 3                 NaN                   NaN                    176
# 4                 NaN                   NaN                    221
#
#    Rating points        Political Party       Occupation           College  \
# 0          842.0                   None          Planter              None
# 1          598.0             Federalist           Lawyer           Harvard
# 2          711.0  Democratic-Republican  Planter, Lawyer  William and Mary
# 3          567.0  Democratic-Republican           Lawyer         Princeton
# 4          602.0  Democratic-Republican           Lawyer  William and Mary
#
#    % electoral  % popular
# 0   100.000000        NaN
# 1    94.964029        NaN
# 2    53.284672        NaN
# 3    69.318182        NaN
# 4    82.805430        NaN

# %% [markdown]
# ## read_html()
# Read data from one or more tables in a Web page. It returns a list of DataFrames, even if there is only one table in the page.

# %%
df_list = pd.read_html('http://money.cnn.com/data/us_markets/', header=0)
print(len(df_list))
for df in df_list:
    print(df.head())
    print('*' * 60)
    
gain_lose = df_list[0]
print(gain_lose.loc[:,['Gainers & Losers', 'Price']])
gain_lose['Price'].plot()
# Out:
# 3
#    Gainers & Losers   Price  Change % Change
# 0    LBL Brands Inc   24.12    2.62  +12.19%
# 1    CPRTCopart Inc   68.92    4.13   +6.37%
# 2  MDTMedtronic PLC   90.89    2.13   +2.40%
# 3    TGTTarget Corp   79.14    1.58   +2.04%
# 4  SNPSSynopsys Inc  117.30    2.21   +1.92%
# ************************************************************
#            Stock Sectors 3 Month % Change
# 0         Communications           +4.62%
# 1      Consumer Durables           -0.14%
# 2  Consumer Non-Durables           +6.61%
# 3    Commercial Services          +10.86%
# 4  Electronic Technology           +1.28%
# ************************************************************
#    GILD    Gilead Sciences Inc.  Unnamed: 2
# 0   LVS   Las Vegas Sands Corp.         NaN
# 1  CELG     Celgene Corporation         NaN
# 2  AAPL              Apple Inc.         NaN
# 3   TXN  Texas Instruments Inc.         NaN
# 4    UA      Under Armour, Inc.         NaN
# ************************************************************
#        Gainers & Losers   Price
# 0        LBL Brands Inc   24.12
# 1        CPRTCopart Inc   68.92
# 2      MDTMedtronic PLC   90.89
# 3        TGTTarget Corp   79.14
# 4      SNPSSynopsys Inc  117.30
# 5        NTAPNetApp Inc   59.88
# 6          HESHess Corp   58.14
# 7  XECCimarex Energy Co   63.63
# 8  DVNDevon Energy Corp   27.30
# 9        APAApache Corp   27.60

# %% [markdown]
# ## read_fwf()
# This function reads files with fixed-width fields. If the fields you want are contiguous, specify the widths of all columns with the *widths* parameter. If they are non-contiguous (you just want to pull out certain columns), specify the columns with the *colspecs* parameter, which takes a list of tuples describing the beginning and end end of each desired column. If neither *widths* or *colspecs* is given, *read_fwf()* tries to infer the columns.

# %%
df_fwf = pd.read_fwf('../DATA/world_median_ages.txt', 
    names=['country', 'median_age'], widths=[7,50,4], index_col=0)
print(df_fwf.head())
print(df_fwf.iloc[1])
# Out:
#                      country  median_age
# 1                     Monaco        52.0
# 2                      Japan        46.0
# 3                    Germany        46.0
# 4  Saint Pierre and Miquelon        45.0
# 5             Virgin Islands        45.0
# country       Japan
# median_age       46
# Name: 2, dtype: object

# %%
ax = df_fwf.iloc[:20].plot(kind='barh', x='country', y='median_age')
print(type(ax))
ax.set_ylabel('Median Age')
# Out:
# <class 'matplotlib.axes._subplots.AxesSubplot'>
# Text(0,0.5,'Median Age')

# %%
URL = "https://en.wikipedia.org/wiki/List_of_rivers_by_length"

df_list = pd.read_html(URL)

print(len(df_list))
df_list[5]
# Out:
# 7
#          0                                                  1              2  \
# 0      NaN                                              River    Length (km)
# 1      1.0  Nile–White Nile–Kagera–Nyabarongo–Mwogo–Rukara...   6,650(7,088)
# 2      2.0              Amazon–Ucayali–Tambo–Ene–Mantaro[n 1]   6,400(6,992)
# 3      3.0                  Yangtze (Chang Jiang; Long River)   6,300(6,418)
# 4      4.0  Mississippi–Missouri–Jefferson–Beaverhead–Red ...           6275
# 5      5.0                        Yenisei–Angara–Selenge–Ider           5539
# 6      6.0                             Yellow River(Huang He)           5464
# 7      7.0                                          Ob–Irtysh           5410
# 8      8.0              Río de la Plata–Paraná–Rio Grande[11]           4880
# 9      9.0                             Congo–Chambeshi(Zaïre)           4700
# 10    10.0                  Amur–Argun–Kherlen(Heilong Jiang)           4444
# 11    11.0                                               Lena           4400
# 12    12.0                              Mekong(Lancang Jiang)           4350
# 13    13.0                       Mackenzie–Slave–Peace–Finlay           4241
# 14    14.0                                              Niger           4200
# 15    15.0                                Brahmaputra–Tsangpo           3848
# 16    16.0            Murray–Darling–Culgoa–Balonne–Condamine      3,672[14]
# 17    17.0                                 Tocantins–Araguaia           3650
# 18    18.0                                              Volga           3645
# 19    19.0                                Indus–Sênggê Zangbo           3610
# 20    20.0                      Shatt al-Arab–Euphrates–Murat           3596
# 21    21.0                  Madeira–Mamoré–Grande–Caine–Rocha           3380
# 22    22.0                                              Purús           3211
# 23    23.0                                              Yukon           3185
# 24    24.0                                      São Francisco  3,180*(2,900)
# 25    25.0                                    Syr Darya–Naryn           3078
# 26    26.0                                  Salween(Nu Jiang)           3060
# 27    27.0  Saint Lawrence–Niagara–Detroit–Saint Clair–Sai...           3058
# 28    28.0                                         Rio Grande           3057
# 29    29.0                                     Lower Tunguska           2989
# ..     ...                                                ...            ...
# 157  155.0                                     Paraíba do Sul           1120
# 158  157.0                                      Jialing River           1119
# 159  158.0                                              Liard           1115
# 160  159.0                                         Cumberland           1105
# 161  160.0                                              White           1162
# 162  161.0                                           Huallaga           1100
# 163  161.0                                             Kwango           1100
# 164  161.0                                               Draa           1100
# 165  164.0                                             Gambia           1094
# 166  165.0                                              Tyung           1092
# 167  165.0                                             Chenab           1086
# 168  166.0                                        Yellowstone           1080
# 169  166.0                                           Ghaghara           1080
# 170  168.0                                         Huai River           1078
# 171  169.0                                               Aras           1072
# 172  170.0                                          Chu River           1067
# 173  171.0                                    Seversky Donets  1,078 (1,053)
# 174  172.0                                            Bermejo           1050
# 175  172.0                                                Fly           1050
# 176  172.0                                          Kuskokwim           1050
# 177  175.0                                          Tennessee           1049
# 178  176.0                                         Oder–Warta           1045
# 179  177.0                                        Aruwimi[22]           1030
# 180  178.0                                            Daugava           1020
# 181  179.0                                               Gila           1015
# 182  180.0                                              Loire           1012
# 183  181.0                                          Essequibo           1010
# 184  181.0                                             Khoper           1010
# 185  183.0                                   Tagus(Tajo/Tejo)           1006
# 186  184.0                                     Flinders River     1,004 [20]
#
#                   3                                    4  \
# 0    Length (miles)  Drainage area(km²)[citation needed]
# 1      4,132(4,404)                              3254555
# 2      3,976(4,345)                              7050000
# 3      3,917(3,988)                              1800000
# 4              3902                              2980000
# 5              3445                              2580000
# 6              3395                               745000
# 7              3364                              2990000
# 8              3030                              2582672
# 9              2922                              3680000
# 10             2763                              1855000
# 11             2736                              2490000
# 12             2705                               810000
# 13             2637                              1790000
# 14             2611                              2090000
# 15             2391                               712035
# 16             2282                              1061000
# 17             2270                               950000
# 18             2266                              1380000
# 19             2250                               960000
# 20             2236                               884000
# 21             2100                              1485200
# 22             1995                                63166
# 23         1,980[9]                               850000
# 24    1,976*(1,802)                               610000
# 25             1913                               219000
# 26             1901                               324000
# 27         1,900[9]                              1030000
# 28         1,900[9]                               570000
# 29             1857                               473000
# ..              ...                                  ...
# 157             696                                  NaN
# 158             695                                  NaN
# 159             693                                  NaN
# 160             687                                46830
# 161         722[24]                                  NaN
# 162             684                                  NaN
# 163             684                               263500
# 164             684                                  NaN
# 165             680                                  NaN
# 166             679                                49800
# 167             675                                  NaN
# 168             671                               114260
# 169             671                               127950
# 170             670                               270000
# 171             665                               102000
# 172             663                                62500
# 173       670 (654)                                98900
# 174             652                                  NaN
# 175             652                                  NaN
# 176             652                                  NaN
# 177             652                                  NaN
# 178             649                               118861
# 179             640                                  NaN
# 180             634                                87900
# 181             631                                  NaN
# 182             629                               115271
# 183             628                                  NaN
# 184             628                                61100
# 185             625                                80100
# 186             624                               109000
#
#                                             5                        6  \
# 0    Average discharge(m³/s)[citation needed]                  Outflow
# 1                                        2800            Mediterranean
# 2                                      209000           Atlantic Ocean
# 3                                       31900           East China Sea
# 4                                       16200           Gulf of Mexico
# 5                                       19600                 Kara Sea
# 6                                        2110                Bohai Sea
# 7                                       12800               Gulf of Ob
# 8                                       18000          Río de la Plata
# 9                                       41800           Atlantic Ocean
# 10                                      11400           Sea of Okhotsk
# 11                                      17100               Laptev Sea
# 12                                      16000          South China Sea
# 13                                      10300             Beaufort Sea
# 14                                       9570           Gulf of Guinea
# 15                             19,800[12][13]                   Ganges
# 16                                        767           Southern Ocean
# 17                                      13598   Atlantic Ocean, Amazon
# 18                                       8080              Caspian Sea
# 19                                       7160              Arabian Sea
# 20                                        856             Persian Gulf
# 21                                      31200                   Amazon
# 22                                       8400                   Amazon
# 23                                       6210               Bering Sea
# 24                                       3300           Atlantic Ocean
# 25                                        703                 Aral Sea
# 26                                  3,153[15]              Andaman Sea
# 27                                      10100   Gulf of Saint Lawrence
# 28                                         82           Gulf of Mexico
# 29                                       3600                  Yenisei
# ..                                        ...                      ...
# 157                                       NaN           Atlantic Ocean
# 158                                       NaN                  Yangtze
# 159                                       NaN                Mackenzie
# 160                                       862              Mississippi
# 161                                       NaN              Mississippi
# 162                                       NaN                  Marañón
# 163                                      2700                    Kasai
# 164                                       NaN           Atlantic Ocean
# 165                                       NaN           Atlantic Ocean
# 166                                       NaN             Vilyuy River
# 167                                       NaN                    Indus
# 168                                       NaN                 Missouri
# 169                                      2990                   Ganges
# 170                                      1110                  Yangtze
# 171                                       285                     Kura
# 172                                       NaN                     none
# 173                                       159                      Don
# 174                                       NaN                 Paraguay
# 175                                       NaN            Gulf of Papua
# 176                                       NaN               Bering Sea
# 177                                       NaN                     Ohio
# 178                                       550               Baltic Sea
# 179                                       NaN                    Congo
# 180                                       678             Gulf of Riga
# 181                                       NaN  Colorado (western U.S.)
# 182                                       840           Atlantic Ocean
# 183                                       NaN           Atlantic Ocean
# 184                                       150                      Don
# 185                                       444           Atlantic Ocean
# 186                                       122      Gulf of Carpentaria
#
#                                                      7
# 0     Countries in the drainage basin[citation needed]
# 1    Ethiopia, Eritrea, Sudan, Uganda, Tanzania, Ke...
# 2    Brazil, Peru, Bolivia, Colombia, Ecuador, Vene...
# 3                                                China
# 4                 United States (98.5%), Canada (1.5%)
# 5                        Russia (97%), Mongolia (2.9%)
# 6                                                China
# 7                  Russia, Kazakhstan, China, Mongolia
# 8    Brazil (46.7%), Argentina (27.7%), Paraguay (1...
# 9    Democratic Republic of the Congo, Central Afri...
# 10                             Russia, China, Mongolia
# 11                                              Russia
# 12   China, Myanmar, Laos, Thailand, Cambodia, Vietnam
# 13                                              Canada
# 14   Nigeria (26.6%), Mali (25.6%), Niger (23.6%), ...
# 15   India (58.0%), China (19.7%), Nepal (9.0%), Ba...
# 16                                           Australia
# 17                                              Brazil
# 18                                              Russia
# 19   Pakistan (93%), India, China, Kashmir (Dispute...
# 20         Iraq (60.5%), Turkey (24.8%), Syria (14.7%)
# 21                               Brazil, Bolivia, Peru
# 22                                        Brazil, Peru
# 23               United States (59.8%), Canada (40.2%)
# 24                                              Brazil
# 25      Kazakhstan, Kyrgyzstan, Uzbekistan, Tajikistan
# 26     China (52.4%), Myanmar (43.9%), Thailand (3.7%)
# 27               Canada (52.1%), United States (47.9%)
# 28               United States (52.1%), Mexico (47.9%)
# 29                                              Russia
# ..                                                 ...
# 157                                             Brazil
# 158                                        P. R. China
# 159                                             Canada
# 160                                      United States
# 161                                      United States
# 162                                               Peru
# 163           Angola, Democratic Republic of the Congo
# 164                                            Morocco
# 165                        The Gambia, Senegal, Guinea
# 166                                             Russia
# 167                                    India, Pakistan
# 168                                      United States
# 169                                India, Nepal, China
# 170                                              China
# 171                  Turkey, Armenia, Azerbaijan, Iran
# 172                             Kyrgyzstan, Kazakhstan
# 173                                    Russia, Ukraine
# 174                                 Argentina, Bolivia
# 175                        Papua New Guinea, Indonesia
# 176                                      United States
# 177                                      United States
# 178                    Poland, Germany, Czech Republic
# 179                   Democratic Republic of the Congo
# 180                            Latvia, Belarus, Russia
# 181                                      United States
# 182                                             France
# 183                                             Guyana
# 184                                             Russia
# 185                                    Spain, Portugal
# 186                                          Australia
#
# [187 rows x 8 columns]
